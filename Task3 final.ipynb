# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales_df = pd.read_csv("sales.csv")
stock_df = pd.read_csv("sensor_stock_levels.csv")

temp_df = pd.read_csv("sensor_storage_temperature.csv")

# %%
sales_df.head(20)
# Out:
#     Unnamed: 0                        transaction_id            timestamp  \
# 0            0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed  2022-03-02 09:51:38
# 1            1  931ad550-09e8-4da6-beaa-8c9d17be9c60  2022-03-06 10:33:59
# 2            2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea  2022-03-04 17:20:21
# 3            3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4  2022-03-02 17:23:58
# 4            4  a81a6cd3-5e0c-44a2-826c-aea43e46c514  2022-03-05 14:32:43
# 5            5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c  2022-03-07 17:59:47
# 6            6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c  2022-03-07 19:36:57
# 7            7  bfffee68-0736-42af-bd3e-4ca77541b0d6  2022-03-07 19:03:20
# 8            8  ce50e984-90cd-4b47-8537-3a4e32e6d314  2022-03-07 11:34:32
# 9            9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b  2022-03-07 09:20:12
# 10          10  3c46e735-8cb6-4ecf-ab3b-94d116651f26  2022-03-06 12:44:29
# 11          11  93c9eeb9-314d-4bd4-b0d9-1e55e97d5273  2022-03-01 14:58:07
# ...

# %%
stock_df.head(20)
# Out:
#     Unnamed: 0                                    id            timestamp  \
# 0            0  4220e505-c247-478d-9831-6b9f87a4488a  2022-03-07 12:13:02
# 1            1  f2612b26-fc82-49ea-8940-0751fdd4d9ef  2022-03-07 16:39:46
# 2            2  989a287f-67e6-4478-aa49-c3a35dac0e2e  2022-03-01 18:17:43
# 3            3  af8e5683-d247-46ac-9909-1a77bdebefb2  2022-03-02 14:29:09
# 4            4  08a32247-3f44-4002-85fb-c198434dd4bb  2022-03-02 13:46:18
# 5            5  98550364-b9c1-42e2-8852-a0e884daf960  2022-03-01 14:51:16
# 6            6  35da168d-715e-4ca1-8755-d317cee4e9b9  2022-03-03 12:59:14
# 7            7  b00838b1-59a6-4f85-81fe-986ed0e46fc2  2022-03-01 12:35:30
# 8            8  4478f269-e631-465f-b490-0d8629dd138d  2022-03-07 13:45:06
# 9            9  ca95cb50-26cb-4d87-8819-baefd68de5d9  2022-03-05 09:18:11
# 10          10  2bdfc59b-0f0e-45df-bbc2-e4ac9fcd4180  2022-03-07 16:53:12
# 11          11  245ce496-f39a-4328-a211-0faa0c2eac20  2022-03-06 14:15:27
# ...

# %%
temp_df.head(20)
# Out:
#     Unnamed: 0                                    id            timestamp  \
# 0            0  d1ca1ef8-0eac-42fc-af80-97106efc7b13  2022-03-07 15:55:20
# 1            1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18  2022-03-01 09:18:22
# 2            2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3  2022-03-04 15:12:26
# 3            3  9500357b-ce15-424a-837a-7677b386f471  2022-03-02 12:30:42
# 4            4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa  2022-03-05 09:09:33
# 5            5  125583af-e280-4627-9cc6-62413af94c6b  2022-03-06 09:39:53
# 6            6  3ef1f91d-f7ef-4bf2-a0f7-2c3720a7432c  2022-03-05 19:21:53
# 7            7  5131c3ed-4f6b-4f52-93c9-fa2717499a80  2022-03-03 19:09:48
# 8            8  0fd6edd9-36d3-4c7c-8184-53e746365067  2022-03-05 15:45:46
# 9            9  04766f4f-a431-4853-92c9-a6b28b7f7abb  2022-03-04 15:18:25
# 10          10  25bb256b-6f45-42d4-8170-81f46842ac1a  2022-03-06 09:49:57
# 11          11  70051222-303f-40d1-b3a7-2a3f1ccd30b1  2022-03-02 09:37:38
# ...

# %%
sales_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')

stock_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')

temp_df.drop(columns=["Unnamed: 0"], inplace=True, errors='ignore')

# %%
import pandas as pd

# Load data
sales_df = pd.read_csv("sales.csv")
stock_df = pd.read_csv("sensor_stock_levels.csv")
temp_df = pd.read_csv("sensor_storage_temperature.csv")

# Convert 'timestamp' column to datetime format in each DataFrame
sales_df['timestamp'] = pd.to_datetime(sales_df['timestamp'])
stock_df['timestamp'] = pd.to_datetime(stock_df['timestamp'])
temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp'])

# %%
sales_df.head(20)
# Out:
#     Unnamed: 0                        transaction_id           timestamp  \
# 0            0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:51:38
# 1            1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:33:59
# 2            2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:20:21
# 3            3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:23:58
# 4            4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:32:43
# 5            5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c 2022-03-07 17:59:47
# 6            6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c 2022-03-07 19:36:57
# 7            7  bfffee68-0736-42af-bd3e-4ca77541b0d6 2022-03-07 19:03:20
# 8            8  ce50e984-90cd-4b47-8537-3a4e32e6d314 2022-03-07 11:34:32
# 9            9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b 2022-03-07 09:20:12
# 10          10  3c46e735-8cb6-4ecf-ab3b-94d116651f26 2022-03-06 12:44:29
# 11          11  93c9eeb9-314d-4bd4-b0d9-1e55e97d5273 2022-03-01 14:58:07
# ...

# %%
stock_df.head(20)
# Out:
#     Unnamed: 0                                    id           timestamp  \
# 0            0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:13:02
# 1            1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:39:46
# 2            2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:17:43
# 3            3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:29:09
# 4            4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:46:18
# 5            5  98550364-b9c1-42e2-8852-a0e884daf960 2022-03-01 14:51:16
# 6            6  35da168d-715e-4ca1-8755-d317cee4e9b9 2022-03-03 12:59:14
# 7            7  b00838b1-59a6-4f85-81fe-986ed0e46fc2 2022-03-01 12:35:30
# 8            8  4478f269-e631-465f-b490-0d8629dd138d 2022-03-07 13:45:06
# 9            9  ca95cb50-26cb-4d87-8819-baefd68de5d9 2022-03-05 09:18:11
# 10          10  2bdfc59b-0f0e-45df-bbc2-e4ac9fcd4180 2022-03-07 16:53:12
# 11          11  245ce496-f39a-4328-a211-0faa0c2eac20 2022-03-06 14:15:27
# ...

# %%
temp_df.head(20)
# Out:
#     Unnamed: 0                                    id           timestamp  \
# 0            0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:55:20
# 1            1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:18:22
# 2            2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:12:26
# 3            3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:30:42
# 4            4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:09:33
# 5            5  125583af-e280-4627-9cc6-62413af94c6b 2022-03-06 09:39:53
# 6            6  3ef1f91d-f7ef-4bf2-a0f7-2c3720a7432c 2022-03-05 19:21:53
# 7            7  5131c3ed-4f6b-4f52-93c9-fa2717499a80 2022-03-03 19:09:48
# 8            8  0fd6edd9-36d3-4c7c-8184-53e746365067 2022-03-05 15:45:46
# 9            9  04766f4f-a431-4853-92c9-a6b28b7f7abb 2022-03-04 15:18:25
# 10          10  25bb256b-6f45-42d4-8170-81f46842ac1a 2022-03-06 09:49:57
# 11          11  70051222-303f-40d1-b3a7-2a3f1ccd30b1 2022-03-02 09:37:38
# ...

# %%
from datetime import datetime

def convert_timestamp_to_hourly(data: pd.DataFrame = None, column: str = None):
  dummy = data.copy()
  new_ts = dummy[column].tolist()
  new_ts = [i.strftime('%Y-%m-%d %H:00:00') for i in new_ts]
  new_ts = [datetime.strptime(i, '%Y-%m-%d %H:00:00') for i in new_ts]
  dummy[column] = new_ts
  return dummy

# ye 15:55:20 ko 15 mai change kar dega i.e hour dekhega

# %%
sales_df = convert_timestamp_to_hourly(sales_df, 'timestamp')
stock_df = convert_timestamp_to_hourly(stock_df, 'timestamp')
temp_df = convert_timestamp_to_hourly(temp_df, 'timestamp')

# %% [markdown]
# # extra

# %%
# extra for copying for understanding 

# Make copies of the DataFrames
sales_copy = sales_df.copy()
stock_copy = stock_df.copy()
temp_copy = temp_df.copy()

# %%
import pandas as pd

# Assuming sales_copy is your DataFrame with the 'timestamp' column
# Convert 'timestamp' column to datetime format
sales_copy['timestamp'] = pd.to_datetime(sales_copy['timestamp'])

# Extract date and hour components
sales_copy['date'] = sales_copy['timestamp'].dt.date
sales_copy['hour'] = sales_copy['timestamp'].dt.hour



# Assuming stock_copy and temp_copy are your DataFrames with the 'timestamp' column
# Convert 'timestamp' column to datetime format for stock_copy
stock_copy['timestamp'] = pd.to_datetime(stock_copy['timestamp'])

# Extract date and hour components for stock_copy
stock_copy['date'] = stock_copy['timestamp'].dt.date
stock_copy['hour'] = stock_copy['timestamp'].dt.hour

# Convert 'timestamp' column to datetime format for temp_copy
temp_copy['timestamp'] = pd.to_datetime(temp_copy['timestamp'])

# Extract date and hour components for temp_copy
temp_copy['date'] = temp_copy['timestamp'].dt.date
temp_copy['hour'] = temp_copy['timestamp'].dt.hour

# %%
sales_copy.head(20)
# Out:
#     Unnamed: 0                        transaction_id           timestamp  \
# 0            0  a1c82654-c52c-45b3-8ce8-4c2a1efe63ed 2022-03-02 09:00:00
# 1            1  931ad550-09e8-4da6-beaa-8c9d17be9c60 2022-03-06 10:00:00
# 2            2  ae133534-6f61-4cd6-b6b8-d1c1d8d90aea 2022-03-04 17:00:00
# 3            3  157cebd9-aaf0-475d-8a11-7c8e0f5b76e4 2022-03-02 17:00:00
# 4            4  a81a6cd3-5e0c-44a2-826c-aea43e46c514 2022-03-05 14:00:00
# 5            5  b5b3c8b9-f496-484d-aa30-4f2efb5ed56c 2022-03-07 17:00:00
# 6            6  4997b1ae-f5aa-4b9f-8fc8-22ad8f19837c 2022-03-07 19:00:00
# 7            7  bfffee68-0736-42af-bd3e-4ca77541b0d6 2022-03-07 19:00:00
# 8            8  ce50e984-90cd-4b47-8537-3a4e32e6d314 2022-03-07 11:00:00
# 9            9  f0700cc9-e6f5-4b9a-add4-05e64b4f495b 2022-03-07 09:00:00
# 10          10  3c46e735-8cb6-4ecf-ab3b-94d116651f26 2022-03-06 12:00:00
# 11          11  93c9eeb9-314d-4bd4-b0d9-1e55e97d5273 2022-03-01 14:00:00
# ...

# %%
stock_copy.head(20)
# Out:
#     Unnamed: 0                                    id           timestamp  \
# 0            0  4220e505-c247-478d-9831-6b9f87a4488a 2022-03-07 12:00:00
# 1            1  f2612b26-fc82-49ea-8940-0751fdd4d9ef 2022-03-07 16:00:00
# 2            2  989a287f-67e6-4478-aa49-c3a35dac0e2e 2022-03-01 18:00:00
# 3            3  af8e5683-d247-46ac-9909-1a77bdebefb2 2022-03-02 14:00:00
# 4            4  08a32247-3f44-4002-85fb-c198434dd4bb 2022-03-02 13:00:00
# 5            5  98550364-b9c1-42e2-8852-a0e884daf960 2022-03-01 14:00:00
# 6            6  35da168d-715e-4ca1-8755-d317cee4e9b9 2022-03-03 12:00:00
# 7            7  b00838b1-59a6-4f85-81fe-986ed0e46fc2 2022-03-01 12:00:00
# 8            8  4478f269-e631-465f-b490-0d8629dd138d 2022-03-07 13:00:00
# 9            9  ca95cb50-26cb-4d87-8819-baefd68de5d9 2022-03-05 09:00:00
# 10          10  2bdfc59b-0f0e-45df-bbc2-e4ac9fcd4180 2022-03-07 16:00:00
# 11          11  245ce496-f39a-4328-a211-0faa0c2eac20 2022-03-06 14:00:00
# ...

# %%
temp_copy.head(20)
# Out:
#     Unnamed: 0                                    id           timestamp  \
# 0            0  d1ca1ef8-0eac-42fc-af80-97106efc7b13 2022-03-07 15:00:00
# 1            1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:00:00
# 2            2  3d47a0c7-1e72-4512-812f-b6b5d8428cf3 2022-03-04 15:00:00
# 3            3  9500357b-ce15-424a-837a-7677b386f471 2022-03-02 12:00:00
# 4            4  c4b61fec-99c2-4c6d-8e5d-4edd8c9632fa 2022-03-05 09:00:00
# 5            5  125583af-e280-4627-9cc6-62413af94c6b 2022-03-06 09:00:00
# 6            6  3ef1f91d-f7ef-4bf2-a0f7-2c3720a7432c 2022-03-05 19:00:00
# 7            7  5131c3ed-4f6b-4f52-93c9-fa2717499a80 2022-03-03 19:00:00
# 8            8  0fd6edd9-36d3-4c7c-8184-53e746365067 2022-03-05 15:00:00
# 9            9  04766f4f-a431-4853-92c9-a6b28b7f7abb 2022-03-04 15:00:00
# 10          10  25bb256b-6f45-42d4-8170-81f46842ac1a 2022-03-06 09:00:00
# 11          11  70051222-303f-40d1-b3a7-2a3f1ccd30b1 2022-03-02 09:00:00
# ...

# %%
import pandas as pd



# Assuming sales_copy, stock_copy, and temp_copy are your DataFrames

# Sort sales_copy DataFrame
sales_copy.sort_values(by=['date', 'hour', 'product_id'], inplace=True)

# Sort stock_copy DataFrame
stock_copy.sort_values(by=['date', 'hour', 'product_id'], inplace=True)

# Sort temp_copy DataFrame
temp_copy.sort_values(by=['date', 'hour'], inplace=True)

# %%
# Display the sorted DataFrames
print("Sorted sales_copy DataFrame:")
sales_copy.head(20)
# Out:
# Sorted sales_copy DataFrame:
#       Unnamed: 0                        transaction_id           timestamp  \
# 7471        7471  2beb6cff-8d77-4723-b11e-ff83736e743f 2022-03-01 09:00:00
# 1259        1259  f99f21e0-bece-45ef-9faa-f24df98408d5 2022-03-01 09:00:00
# 5942        5942  bf65942d-dbb5-4a34-ade1-900a1159d9a3 2022-03-01 09:00:00
# 2765        2765  5d28ed8a-6426-4d81-b3e9-b3775bed9623 2022-03-01 09:00:00
# 3071        3071  b9b5a22a-d2c5-4a14-b1ca-ce1e1f447346 2022-03-01 09:00:00
# 300          300  96bc9c31-3315-476d-9dc1-732af1133e50 2022-03-01 09:00:00
# 718          718  cfef831d-db4b-4270-9667-e09022f67196 2022-03-01 09:00:00
# 754          754  0e78a113-7c1e-4441-b314-35ac51840e3d 2022-03-01 09:00:00
# 884          884  7681d9f8-867f-4897-9925-2a3ea1377828 2022-03-01 09:00:00
# 1876        1876  601d7f91-3abd-4d31-af2e-bd34e2fe39f1 2022-03-01 09:00:00
# 4373        4373  5ad37b0d-aabf-4bca-a93a-a1dc3c73dd33 2022-03-01 09:00:00
# ...

# %%
print("\nSorted stock_copy DataFrame:")

stock_copy.head(20)
# Out:
# Sorted stock_copy DataFrame:
#        Unnamed: 0                                    id           timestamp  \
# 11673       11673  231c9b10-b8e8-438e-92d0-7e7a5083d9ed 2022-03-01 09:00:00
# 6820         6820  d8682bb8-a496-492c-b07a-ef9fcf1ce6dc 2022-03-01 09:00:00
# 12840       12840  aa19a275-8dda-4461-93e6-d2039f4f68bf 2022-03-01 09:00:00
# 12211       12211  d64c1f56-8bc9-4811-9259-9f74b32e9847 2022-03-01 09:00:00
# 11473       11473  7440962d-b617-4e52-af1a-fb3e1ba580ed 2022-03-01 09:00:00
# 9299         9299  e7fe0d47-4ce3-4feb-a273-33404db36bde 2022-03-01 09:00:00
# 9941         9941  23644ee6-c0a4-4799-a450-7acdfe057ddd 2022-03-01 09:00:00
# 2095         2095  c0af0090-f749-440d-95e6-d93d1741951e 2022-03-01 09:00:00
# 494           494  d6463cbb-d139-4292-9a49-5c1efdfa8221 2022-03-01 09:00:00
# 8242         8242  67397056-6aea-48ef-ba90-acb68dbfe442 2022-03-01 09:00:00
# 7881         7881  d114f6df-69cd-4a54-8d00-a6dc679f8746 2022-03-01 09:00:00
# ...

# %%
print("\nSorted temp_copy DataFrame:")

temp_copy.head(20)
# Out:
# Sorted temp_copy DataFrame:
#       Unnamed: 0                                    id           timestamp  \
# 1              1  4b8a66c4-0f3a-4f16-826f-8cf9397e9d18 2022-03-01 09:00:00
# 26            26  abf827a8-548d-43d2-a433-716e458946af 2022-03-01 09:00:00
# 89            89  a298d1e3-b68c-4ce2-a06b-9cc4b7361bc2 2022-03-01 09:00:00
# 117          117  f969a36f-75c1-4dc0-a8e1-4bb4659ce7a1 2022-03-01 09:00:00
# 294          294  2fd942cb-3f9d-4459-aeb9-697fe58eb744 2022-03-01 09:00:00
# 545          545  69b72acd-8e52-4b43-a8ba-269181760767 2022-03-01 09:00:00
# 684          684  6d89f313-0a69-43d1-a66b-4ed23a28cb3c 2022-03-01 09:00:00
# 697          697  ff5de98a-b1c0-40c4-ab8a-74f5db3bd100 2022-03-01 09:00:00
# 735          735  fcacb814-fe4f-450a-924d-fc643318c216 2022-03-01 09:00:00
# 787          787  852225bd-1f79-4f40-92ad-fb9273b8c8f0 2022-03-01 09:00:00
# 843          843  2c88e6da-92cf-4457-abd7-bcd5ec95dd49 2022-03-01 09:00:00
# ...

# %%
#storing file in excel for easy view

# %%
sales_copy.to_excel('sales_copy.xlsx', index=False)

stock_copy.to_excel('stock_copy.xlsx', index=False)

temp_copy.to_excel('temp_copy.xlsx', index=False)

# %%
# bas ye hi 3 column bachenge baki hath jayenge

sales_agg_copy = sales_copy.groupby(['timestamp', 'product_id']).agg({'quantity': 'sum'}).reset_index()
sales_agg_copy
# Out:
#                timestamp                            product_id  quantity
# 0    2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03         3
# 1    2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0         3
# 2    2022-03-01 09:00:00  03a2557a-aa12-4add-a6d4-77dc36342067         3
# 3    2022-03-01 09:00:00  049b2171-0eeb-4a3e-bf98-0c290c7821da         7
# 4    2022-03-01 09:00:00  04da844d-8dba-4470-9119-e534d52a03a0        11
# ...                  ...                                   ...       ...
# 6212 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9         3
# 6213 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443         3
# 6214 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43         2
# 6215 2022-03-07 19:00:00  fd66ac0b-3498-4613-8ec0-764686b0d864         1
# 6216 2022-03-07 19:00:00  fd77b5cb-498c-40ca-95d1-0f87f13dd0d8         1
#
# [6217 rows x 3 columns]

# %%
stock_agg_copy = stock_copy.groupby(['timestamp', 'product_id']).agg({'estimated_stock_pct': 'mean'}).reset_index()
stock_agg_copy.head(20)
# Out:
#              timestamp                            product_id  \
# 0  2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1  2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2  2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3  2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4  2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# 5  2022-03-01 09:00:00  0998699f-2fec-454e-b8b0-4f701947fef6
# 6  2022-03-01 09:00:00  0cb046e3-a86b-47ae-9751-3b0f9c596f99
# 7  2022-03-01 09:00:00  0cc2986e-934c-447e-8f7b-a57b2ceb8693
# 8  2022-03-01 09:00:00  0ddc2379-adba-4fb0-aa97-19fcafc738a1
# 9  2022-03-01 09:00:00  0ec3890d-f4be-48a4-9358-291b3da7f578
# 10 2022-03-01 09:00:00  0f80f0b5-2488-46e1-a8b7-8bb24be25a40
# 11 2022-03-01 09:00:00  100ab1ec-39f5-41bd-984f-485039575827
# 12 2022-03-01 09:00:00  107cb949-f28d-4a4d-969b-05d17f0f53a8
# 13 2022-03-01 09:00:00  146d5e4d-992a-4db7-904d-b8af359b80a7
# ...

# %%
temp_agg_copy = temp_copy.groupby(['timestamp']).agg({'temperature': 'mean'}).reset_index()
temp_agg_copy.head(20)
# Out:
#              timestamp  temperature
# 0  2022-03-01 09:00:00    -0.028850
# 1  2022-03-01 10:00:00     1.284314
# 2  2022-03-01 11:00:00    -0.560000
# 3  2022-03-01 12:00:00    -0.537721
# 4  2022-03-01 13:00:00    -0.188734
# 5  2022-03-01 14:00:00     0.816969
# 6  2022-03-01 15:00:00     0.337059
# 7  2022-03-01 16:00:00     0.560063
# 8  2022-03-01 17:00:00    -0.376415
# 9  2022-03-01 18:00:00    -1.395743
# 10 2022-03-01 19:00:00     0.508333
# 11 2022-03-02 09:00:00    -0.672900
# 12 2022-03-02 10:00:00    -0.856840
# 13 2022-03-02 11:00:00    -0.268298
# 14 2022-03-02 12:00:00     0.341860
# 15 2022-03-02 13:00:00    -0.332065
# 16 2022-03-02 14:00:00    -0.761559
# 17 2022-03-02 15:00:00    -0.084086
# 18 2022-03-02 16:00:00    -0.234215
# 19 2022-03-02 17:00:00    -0.407567

# %%
sales_agg_copy.to_excel('sales_agg_copy.xlsx', index=False)

stock_agg_copy.to_excel('stock_agg_copy.xlsx', index=False)

temp_agg_copy.to_excel('temp_agg_copy.xlsx', index=False)

# %%
merged_stock_sales_copy_df = stock_agg_copy.merge(sales_agg_copy, on=['timestamp', 'product_id'], how='left')

# %%
merged_stock_sales_copy_df
# Out:
#                 timestamp                            product_id  \
# 0     2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1     2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2     2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3     2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4     2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# ...                   ...                                   ...
# 10840 2022-03-07 19:00:00  ecac012c-1dec-41d4-9ebd-56fb7166f6d9
# 10841 2022-03-07 19:00:00  ed7f6b14-67c9-42a4-8576-c803020eedda
# 10842 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9
# 10843 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443
# 10844 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43
#
#        estimated_stock_pct  quantity
# 0                     0.89       3.0
# 1                     0.14       3.0
# 2                     0.67       NaN
# 3                     0.82       NaN
# ...

# %%
merged_stock_sales_copy_df.to_excel('merged_stock_sales_copy_df.xlsx', index=False)

# %%
merged_stock_sales_copy_temp_df = merged_stock_sales_copy_df.merge(temp_agg_copy, on='timestamp', how='left')

# %%
merged_stock_sales_copy_temp_df.to_excel('merged_stock_sales_copy_temp_df.xlsx', index=False)

# %%
merged_stock_sales_copy_temp_df['quantity'] = merged_stock_sales_copy_temp_df['quantity'].fillna(0)

# %%
#quantity mai jha kuch naa tha bha 0 fill kar diya


merged_stock_sales_copy_temp_df.head()
# Out:
#             timestamp                            product_id  \
# 0 2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1 2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2 2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3 2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4 2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
#
#    estimated_stock_pct  quantity  temperature
# 0                 0.89       3.0     -0.02885
# 1                 0.14       3.0     -0.02885
# 2                 0.67       0.0     -0.02885
# 3                 0.82       0.0     -0.02885
# 4                 0.05       0.0     -0.02885

# %%
'''
It seems like you're trying to extract unique product categories and their corresponding prices from a DataFrame called sales_df. You're correctly creating separate DataFrames for categories and prices. Here's what you're doing step by step:

Extracting product_id and category columns from sales_df and removing duplicate rows to get unique product categories.
Extracting product_id and unit_price columns from sales_df and removing duplicate rows to get unique product prices.
Your code looks fi

'''
# Out:
# "\nIt seems like you're trying to extract unique product categories and their corresponding prices from a DataFrame called sales_df. You're correctly creating separate DataFrames for categories and prices. Here's what you're doing step by step:\n\nExtracting product_id and category columns from sales_df and removing duplicate rows to get unique product categories.\nExtracting product_id and unit_price columns from sales_df and removing duplicate rows to get unique product prices.\nYour code looks fi\n\n"

# %%
# sales dataframe se 'product_id', 'category' nikal ke product_categories  naya data frame banaya

# sales dataframe se 'product_id', 'unit_price' nikal ke product_price  naya data frame banaya


product_categories_copy = sales_copy[['product_id', 'category']]
product_categories_copy = product_categories_copy.drop_duplicates()

product_price_copy = sales_copy[['product_id', 'unit_price']]
product_price_copy = product_price_copy.drop_duplicates()

# %%
product_categories_copy
# Out:
#                                 product_id               category
# 7471  00e120bb-89d6-4df5-bc48-a051148e3d03                kitchen
# 1259  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0             vegetables
# 5942  03a2557a-aa12-4add-a6d4-77dc36342067                 baking
# 2765  049b2171-0eeb-4a3e-bf98-0c290c7821da           canned foods
# 300   04da844d-8dba-4470-9119-e534d52a03a0                  fruit
# ...                                    ...                    ...
# 3644  5adfc643-aa8e-4140-b2c3-98a946444632  condiments and sauces
# 7605  bc6187a9-d508-482b-9ca6-590d1cc7524f      cleaning products
# 7693  20a9bd7b-daff-4b8b-bdc1-2e8f9a0277fa      cleaning products
# 3774  63df792c-9cab-4bf6-9f9c-07fc35175219  condiments and sauces
# 2576  8653ceaf-6e7f-498c-b8ca-5a6bb6a15dae       spices and herbs
#
# [300 rows x 2 columns]

# %%
product_price_copy
# Out:
#                                 product_id  unit_price
# 7471  00e120bb-89d6-4df5-bc48-a051148e3d03       11.19
# 1259  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0        1.49
# 5942  03a2557a-aa12-4add-a6d4-77dc36342067        5.99
# 2765  049b2171-0eeb-4a3e-bf98-0c290c7821da        2.49
# 300   04da844d-8dba-4470-9119-e534d52a03a0        0.49
# ...                                    ...         ...
# 3644  5adfc643-aa8e-4140-b2c3-98a946444632        9.19
# 7605  bc6187a9-d508-482b-9ca6-590d1cc7524f       14.19
# 7693  20a9bd7b-daff-4b8b-bdc1-2e8f9a0277fa       13.49
# 3774  63df792c-9cab-4bf6-9f9c-07fc35175219        4.99
# 2576  8653ceaf-6e7f-498c-b8ca-5a6bb6a15dae        2.49
#
# [300 rows x 2 columns]

# %%
merged_stock_sales_copy_temp_product_categories_df = merged_stock_sales_copy_temp_df.merge(product_categories_copy, on="product_id", how="left")

# %%
 merged_stock_sales_copy_temp_product_categories_product_price_df = merged_stock_sales_copy_temp_product_categories_df.merge(product_price_copy, on="product_id", how="left")

# %%
merged_stock_sales_copy_temp_product_categories_df.to_excel('merged_stock_sales_copy_temp_product_categories_df.xlsx', index=False)

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df.to_excel('merged_stock_sales_copy_temp_product_categories_product_price_df.xlsx', index=False)

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp_day_of_month'] = merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp'].dt.day
merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp_day_of_week'] = merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp'].dt.dayofweek
merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp_hour'] = merged_stock_sales_copy_temp_product_categories_product_price_df['timestamp'].dt.hour

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df
# Out:
#                 timestamp                            product_id  \
# 0     2022-03-01 09:00:00  00e120bb-89d6-4df5-bc48-a051148e3d03
# 1     2022-03-01 09:00:00  01f3cdd9-8e9e-4dff-9b5c-69698a0388d0
# 2     2022-03-01 09:00:00  01ff0803-ae73-4234-971d-5713c97b7f4b
# 3     2022-03-01 09:00:00  0363eb21-8c74-47e1-a216-c37e565e5ceb
# 4     2022-03-01 09:00:00  03f0b20e-3b5b-444f-bc39-cdfa2523d4bc
# ...                   ...                                   ...
# 10840 2022-03-07 19:00:00  ecac012c-1dec-41d4-9ebd-56fb7166f6d9
# 10841 2022-03-07 19:00:00  ed7f6b14-67c9-42a4-8576-c803020eedda
# 10842 2022-03-07 19:00:00  edf4ac93-4e14-4a3d-8c60-e715210cf3f9
# 10843 2022-03-07 19:00:00  f01b189c-6345-4639-a8d1-89e1fc67c443
# 10844 2022-03-07 19:00:00  f3bec808-bee0-4597-a129-53a3a2805a43
#
#        estimated_stock_pct  quantity  temperature        category  unit_price  \
# 0                     0.89       3.0    -0.028850         kitchen       11.19
# ...

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df.drop(columns=['timestamp'], inplace=True)

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df
# Out:
#                                  product_id  estimated_stock_pct  quantity  \
# 0      00e120bb-89d6-4df5-bc48-a051148e3d03                 0.89       3.0
# 1      01f3cdd9-8e9e-4dff-9b5c-69698a0388d0                 0.14       3.0
# 2      01ff0803-ae73-4234-971d-5713c97b7f4b                 0.67       0.0
# 3      0363eb21-8c74-47e1-a216-c37e565e5ceb                 0.82       0.0
# 4      03f0b20e-3b5b-444f-bc39-cdfa2523d4bc                 0.05       0.0
# ...                                     ...                  ...       ...
# 10840  ecac012c-1dec-41d4-9ebd-56fb7166f6d9                 0.50       4.0
# 10841  ed7f6b14-67c9-42a4-8576-c803020eedda                 0.26       0.0
# 10842  edf4ac93-4e14-4a3d-8c60-e715210cf3f9                 0.78       3.0
# 10843  f01b189c-6345-4639-a8d1-89e1fc67c443                 0.92       3.0
# 10844  f3bec808-bee0-4597-a129-53a3a2805a43                 0.01       2.0
#
# ...

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df = pd.get_dummies(merged_stock_sales_copy_temp_product_categories_product_price_df, columns=['category'])

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df
# Out:
#                                  product_id  estimated_stock_pct  quantity  \
# 0      00e120bb-89d6-4df5-bc48-a051148e3d03                 0.89       3.0
# 1      01f3cdd9-8e9e-4dff-9b5c-69698a0388d0                 0.14       3.0
# 2      01ff0803-ae73-4234-971d-5713c97b7f4b                 0.67       0.0
# 3      0363eb21-8c74-47e1-a216-c37e565e5ceb                 0.82       0.0
# 4      03f0b20e-3b5b-444f-bc39-cdfa2523d4bc                 0.05       0.0
# ...                                     ...                  ...       ...
# 10840  ecac012c-1dec-41d4-9ebd-56fb7166f6d9                 0.50       4.0
# 10841  ed7f6b14-67c9-42a4-8576-c803020eedda                 0.26       0.0
# 10842  edf4ac93-4e14-4a3d-8c60-e715210cf3f9                 0.78       3.0
# 10843  f01b189c-6345-4639-a8d1-89e1fc67c443                 0.92       3.0
# 10844  f3bec808-bee0-4597-a129-53a3a2805a43                 0.01       2.0
#
# ...

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df.drop(columns=['product_id'], inplace=True)

# %%
merged_stock_sales_copy_temp_product_categories_product_price_df
# Out:
#        estimated_stock_pct  quantity  temperature  unit_price  \
# 0                     0.89       3.0    -0.028850       11.19
# 1                     0.14       3.0    -0.028850        1.49
# 2                     0.67       0.0    -0.028850       14.19
# 3                     0.82       0.0    -0.028850       20.19
# 4                     0.05       0.0    -0.028850        8.19
# ...                    ...       ...          ...         ...
# 10840                 0.50       4.0    -0.165077        4.99
# 10841                 0.26       0.0    -0.165077       19.99
# 10842                 0.78       3.0    -0.165077        6.99
# 10843                 0.92       3.0    -0.165077       14.99
# 10844                 0.01       2.0    -0.165077        5.19
#
#        timestamp_day_of_month  timestamp_day_of_week  timestamp_hour  \
# 0                           1                      1               9
# 1                           1                      1               9
# ...

# %%
X = merged_stock_sales_copy_temp_product_categories_product_price_df.drop(columns=['estimated_stock_pct'])
y = merged_stock_sales_copy_temp_product_categories_product_price_df['estimated_stock_pct']

# %%
X
# Out:
#        quantity  temperature  unit_price  timestamp_day_of_month  \
# 0           3.0    -0.028850       11.19                       1
# 1           3.0    -0.028850        1.49                       1
# 2           0.0    -0.028850       14.19                       1
# 3           0.0    -0.028850       20.19                       1
# 4           0.0    -0.028850        8.19                       1
# ...         ...          ...         ...                     ...
# 10840       4.0    -0.165077        4.99                       7
# 10841       0.0    -0.165077       19.99                       7
# 10842       3.0    -0.165077        6.99                       7
# 10843       3.0    -0.165077       14.99                       7
# 10844       2.0    -0.165077        5.19                       7
#
#        timestamp_day_of_week  timestamp_hour  category_baby products  \
# 0                          1               9                       0
# ...

# %%
y
# Out:
# 0        0.89
# 1        0.14
# 2        0.67
# 3        0.82
# 4        0.05
#          ...
# 10840    0.50
# 10841    0.26
# 10842    0.78
# 10843    0.92
# 10844    0.01
# Name: estimated_stock_pct, Length: 10845, dtype: float64

# %%
X.to_excel('X.xlsx', index=False)

y.to_excel('y.xlsx', index=False)

# %%
K = 10
split = 0.75

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler

accuracy = []

for fold in range(0, K):

    # Instantiate algorithm
    model = RandomForestRegressor()
    scaler = StandardScaler()

    # Create training and test samples
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=split, random_state=42)

    # Scale X data
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)

    # Train model
    trained_model = model.fit(X_train, y_train)

    # Generate predictions on test sample
    y_pred = trained_model.predict(X_test)

    # Compute accuracy
    mae = mean_absolute_error(y_true=y_test, y_pred=y_pred)
    accuracy.append(mae)
    print(f"Fold {fold + 1}: MAE = {mae:.3f}")

print(f"Average MAE: {(sum(accuracy) / len(accuracy)):.2f}")
# Out:
# Fold 1: MAE = 0.237
# Fold 2: MAE = 0.237
# Fold 3: MAE = 0.236
# Fold 4: MAE = 0.236
# Fold 5: MAE = 0.237
# Fold 6: MAE = 0.237
# Fold 7: MAE = 0.236
# Fold 8: MAE = 0.237
# Fold 9: MAE = 0.236
# Fold 10: MAE = 0.236
# Average MAE: 0.24

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
features = [i.split("__")[0] for i in X.columns]
importances = model.feature_importances_
indices = np.argsort(importances)

fig, ax = plt.subplots(figsize=(10, 20))
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()

# %%
# Print feature importances as numbers
for i in range(len(indices)):
    print(f"{features[indices[i]]}: {importances[indices[i]]}")
# Out:
# category_fruit: 0.007182255527950328
# category_vegetables: 0.007941314075378852
# category_meat: 0.009082388122790315
# category_medicine: 0.009223827927693013
# category_snacks: 0.009480566283536959
# category_pets: 0.010091247254994409
# category_dairy: 0.010493363296714362
# category_spices and herbs: 0.010579135925779838
# category_kitchen: 0.010610902676501896
# category_seafood: 0.010646580458844992
# category_packaged foods: 0.010757589993778328
# category_refrigerated items: 0.01081661668317852
# category_canned foods: 0.012866794140557549
# category_condiments and sauces: 0.01296582617309374
# category_baby products: 0.012992389498656411
# category_baking: 0.013195222790739137
# category_cleaning products: 0.013552779880059523
# category_cheese: 0.014164007878817015
# category_baked goods: 0.01491065611436997
# category_personal care: 0.015142376531254099
# category_frozen: 0.01538303227567872
# category_beverages: 0.015399000072087403
# ...

# %%
# Plot pie chart for feature categories
plt.figure(figsize=(8, 8))
X.columns.str.split('_').str[0].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=sns.color_palette('pastel'), startangle=140)
plt.title('Proportion of Feature Categories')
plt.ylabel('')
plt.show()
